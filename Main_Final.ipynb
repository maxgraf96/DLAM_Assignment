# %%
# %run Main.py
# Out:
# Loading autoencoder model...
# Autoencoder model successfully loaded.
# Loading U-Net model...
# U-Net model loaded.

# %%
import IPython.display as ipd

# sig = pipeline("data" + sep + "piano" + sep + "chp_op18.wav")
sig = pipeline("data" + sep + "test" + sep + "mz_330_1.wav")
sig = librosa.util.normalize(sig)
ipd.Audio(sig, rate=sample_rate)
# Out:
# Original
# Original synth
# /homes/mg315/venv_ecs7013P/lib/python3.6/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# No synth file found for input
# Final output
# Converting spectrogram back to signal...
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
